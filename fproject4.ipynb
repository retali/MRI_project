# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

#This is to demostrate the degree of correlation that exist between the GDP per capita rate
#and the Macroeconomic Result Index (MRI)
#It was calculated the Rsqueared for each function in every country
#The function is Y = f(MRI)
#Y = GDP percapita rate
#MRI = Macroeconomic Result Index

#Len of data = 40 countries

Data = "allmri.csv"
dataW = pd.read_csv(Data)
dataW
# Out:
#           Countries  MRImean  Rsquared
# 0           Bolivia      409      0.63
# 1            Brazil      104      0.77
# 2             Chile      277      0.70
# 3          Colombia      169      0.78
# 4           Ecuador      212      0.61
# 5            Mexico      175      0.64
# 6          Paraguay      219      0.78
# 7              Peru      271      0.48
# 8           Uruguay      118      0.67
# 9         Venezuela       73      0.74
# 10        Argentina      153      0.90
# 11       Costa Rica      225      0.75
# 12      El Salvador      195      0.76
# 13        Nicaragua      200      0.88
# 14           Panama      420      0.81
# 15          Austria      285      0.95
# 16          Belgium      166      0.93
# 17         Bulgaria      144      0.55
# 18          Croatia      126      0.67
# 19         Czechrep      319      0.85
# 20          Denmark      209      0.88
# 21          Finland      176      0.95
# 22           France      137      0.96
# ...

# %%
plt.style.use('ggplot')

# histogram of the R-squared

dataW.Rsquared.plot(kind = 'hist', color = 'purple', edgecolor = 'black', figsize = (10,7))
plt.title("Distribution R-squared", size = 24)
plt.xlabel('R-squared', size = 18)
plt.ylabel('Frequency', size = 18)
# Out:
# Text(0, 0.5, 'Frequency')
